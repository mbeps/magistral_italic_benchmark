# %%
# %%
from magistral_benchmark import MagistralBenchmarkConfig, MagistralReasoningBenchmark

# %%
# %%
config = MagistralBenchmarkConfig(
    model_name="mistralai/Magistral-Small-2506",
    tokenizer_name="mistralai/Mistral-Nemo-Instruct-2407",
    batch_size=6,               # Slightly smaller for reasoning mode
    min_vram_gb=8,              # Lower requirement due to 4-bit quantization
    test_file="./data/test.jsonl",
    max_new_tokens=500,         # Extra tokens for reasoning
    max_eval_samples=1000,      # Subset for faster testing
    system_message="Sei un assistente utile e intelligente.",
    output_prefix="magistral_small_reasoning",
    # Quantization settings
    use_quantization=True,
    quantization_type="nf4",
    quantization_compute_dtype="float16",
    # Optimizations
    use_flash_attention=True,
    use_torch_compile=True,
)

# %%
# %%
config.print_config()
# Out:
# ============================================================
# MAGISTRAL BENCHMARK CONFIGURATION
# ============================================================
# ✓ Model: mistralai/Magistral-Small-2506
# ✓ Tokenizer: mistralai/Mistral-Nemo-Instruct-2407
# ✓ Test file: ./data/test.jsonl
# ✓ Max samples: 1000
# ✓ Batch size: 6
# ✓ Max new tokens: 500
# ✓ Min VRAM required: 8GB
# ✓ Quantization: nf4 (float16)
# ✓ Flash Attention 2: Enabled
# ✓ torch.compile: Enabled
# ✓ Output prefix: magistral_small_reasoning
# ✓ System message: Sei un assistente utile e intelligente.
# ============================================================

# %%
# %%
benchmark = MagistralReasoningBenchmark(config)
# Out:
# ✅ CUDA optimizations enabled (TF32, cuDNN benchmark)
# ✅ CUDA available: True
# GPU: NVIDIA GeForce RTX 3090
# VRAM: 23.6 GB
# ✅ GPU has sufficient VRAM for the model

# %%
# %%
results, accuracy, category_stats = benchmark.run_benchmark()
# Out:
# ============================================================
# MAGISTRAL REASONING BENCHMARK
# 🤔 THINKING MODE ENABLED
# ============================================================
#
# ============================================================
# MAGISTRAL BENCHMARK CONFIGURATION
# ============================================================
# ✓ Model: mistralai/Magistral-Small-2506
# ✓ Tokenizer: mistralai/Mistral-Nemo-Instruct-2407
# ✓ Test file: ./data/test.jsonl
# ✓ Max samples: 1000
# ✓ Batch size: 6
# ✓ Max new tokens: 500
# ✓ Min VRAM required: 8GB
# ✓ Quantization: nf4 (float16)
# ✓ Flash Attention 2: Enabled
# ✓ torch.compile: Enabled
# ✓ Output prefix: magistral_small_reasoning
# ✓ System message: Sei un assistente utile e intelligente.
# ============================================================
# ✓ Reasoning: ENABLED
# ✓ Aggressive prompting: YES (max 3 sentences)
#
# 📚 Loading ITALIC dataset...
# Loaded 10000 questions
#
# Original dataset category distribution:
#   art_history: 980 questions
#   civic_education: 973 questions
#   current_events: 92 questions
#   geography: 979 questions
#   history: 978 questions
#   lexicon: 979 questions
#   literature: 984 questions
#   morphology: 140 questions
#   orthography: 971 questions
#   synonyms_and_antonyms: 971 questions
#   syntax: 973 questions
#   tourism: 980 questions
#
# Creating uniform subset with 1000 samples:
#   art_history: selected 84 / 980 questions
#   civic_education: selected 84 / 973 questions
#   current_events: selected 84 / 92 questions
#   geography: selected 84 / 979 questions
#   history: selected 83 / 978 questions
#   lexicon: selected 83 / 979 questions
#   literature: selected 83 / 984 questions
#   morphology: selected 83 / 140 questions
#   orthography: selected 83 / 971 questions
#   synonyms_and_antonyms: selected 83 / 971 questions
#   syntax: selected 83 / 973 questions
#   tourism: selected 83 / 980 questions
#
# Final subset: 1000 questions
#
# Using 1000 questions for evaluation
# Categories: {'art_history': 84, 'civic_education': 84, 'current_events': 84, 'geography': 84, 'history': 83, 'lexicon': 83, 'literature': 83, 'morphology': 83, 'orthography': 83, 'synonyms_and_antonyms': 83, 'syntax': 83, 'tourism': 83}
# 🔄 Loading mistralai/Magistral-Small-2506 with REASONING support...
# Loading tokenizer: mistralai/Mistral-Nemo-Instruct-2407
# tokenizer_config.json:   0%|          | 0.00/181k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/9.26M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/414 [00:00<?, ?B/s]
# ⚠️ Flash Attention 2 not available - using standard attention
# Loading model with optimizations...
# config.json:   0%|          | 0.00/619 [00:00<?, ?B/s]
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# Fetching 10 files:   0%|          | 0/10 [00:00<?, ?it/s]
# model-00008-of-00010.safetensors:   0%|          | 0.00/4.78G [00:00<?, ?B/s]
# model-00005-of-00010.safetensors:   0%|          | 0.00/4.78G [00:00<?, ?B/s]
# model-00001-of-00010.safetensors:   0%|          | 0.00/4.78G [00:00<?, ?B/s]
# model-00007-of-00010.safetensors:   0%|          | 0.00/4.89G [00:00<?, ?B/s]
# model-00003-of-00010.safetensors:   0%|          | 0.00/4.78G [00:00<?, ?B/s]
# model-00006-of-00010.safetensors:   0%|          | 0.00/4.78G [00:00<?, ?B/s]
# model-00002-of-00010.safetensors:   0%|          | 0.00/4.78G [00:00<?, ?B/s]
# model-00004-of-00010.safetensors:   0%|          | 0.00/4.89G [00:00<?, ?B/s]
# model-00009-of-00010.safetensors:   0%|          | 0.00/4.78G [00:00<?, ?B/s]
# model-00010-of-00010.safetensors:   0%|          | 0.00/3.90G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/10 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# Compiling model with torch.compile for optimization...
# The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# ✅ Model compiled successfully!
# ✅ Model loaded with REASONING support!
# ✅ Sampling params: temp=0.1, top_p=0.95, top_k=20 (reasoning mode)
# GPU Memory - Allocated: 13.18 GB, Available: 9.12 GB
# 🚀 Optimal batch size for reasoning mode: 6
#
# 🧪 Testing inference with REASONING enabled...
# Question: Chi è il regista del film "La strada"?...
# Test response length: 340 chars
# Expected answer: 'C'
# Extracted answer: 'C'
# Correct: True
#
# ==================================================
# STARTING REASONING EVALUATION
# ==================================================
#
# 🤔 Evaluating mistralai/Magistral-Small-2506 WITH REASONING on 1000 questions...
# ⚡ Using aggressive prompting to minimize thinking time
# Evaluating (with reasoning):   0%|          | 0/167 [00:00<?, ?it/s]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   1%|          | 1/167 [00:20<55:36, 20.10s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   1%|          | 2/167 [00:36<49:05, 17.85s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   2%|▏         | 3/167 [01:15<1:14:59, 27.44s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   2%|▏         | 4/167 [01:31<1:02:37, 23.05s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   3%|▎         | 5/167 [01:48<56:00, 20.74s/it]  The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   4%|▎         | 6/167 [02:15<1:01:15, 22.83s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   4%|▍         | 7/167 [02:31<55:06, 20.66s/it]  The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   5%|▍         | 8/167 [03:02<1:03:54, 24.12s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   5%|▌         | 9/167 [03:23<1:00:51, 23.11s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   6%|▌         | 10/167 [03:44<58:52, 22.50s/it] The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   7%|▋         | 11/167 [04:05<56:47, 21.84s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   7%|▋         | 12/167 [04:37<1:04:42, 25.05s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   8%|▊         | 13/167 [05:07<1:07:59, 26.49s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   8%|▊         | 14/167 [05:17<55:10, 21.64s/it]  The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):   9%|▉         | 15/167 [05:40<55:36, 21.95s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  10%|▉         | 16/167 [05:56<50:53, 20.22s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  10%|█         | 17/167 [06:11<46:11, 18.48s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  11%|█         | 18/167 [06:41<55:05, 22.19s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  11%|█▏        | 19/167 [07:06<56:11, 22.78s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  12%|█▏        | 20/167 [07:48<1:10:35, 28.81s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  13%|█▎        | 21/167 [08:06<1:01:58, 25.47s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  13%|█▎        | 22/167 [08:22<54:35, 22.59s/it]  The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  14%|█▍        | 23/167 [08:47<55:36, 23.17s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):
/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  81%|████████  | 135/167 [50:38<10:57, 20.56s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  81%|████████▏ | 136/167 [51:10<12:27, 24.12s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  82%|████████▏ | 137/167 [51:32<11:43, 23.46s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  83%|████████▎ | 138/167 [51:53<10:54, 22.57s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  83%|████████▎ | 139/167 [52:45<14:42, 31.51s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  84%|████████▍ | 140/167 [53:45<17:58, 39.93s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  84%|████████▍ | 141/167 [54:12<15:37, 36.06s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  85%|████████▌ | 142/167 [54:45<14:41, 35.27s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  86%|████████▌ | 143/167 [55:01<11:47, 29.50s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  86%|████████▌ | 144/167 [55:27<10:52, 28.38s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  87%|████████▋ | 145/167 [55:57<10:33, 28.81s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  87%|████████▋ | 146/167 [56:12<08:42, 24.87s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  88%|████████▊ | 147/167 [56:35<08:03, 24.17s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  89%|████████▊ | 148/167 [56:50<06:44, 21.29s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  89%|████████▉ | 149/167 [57:21<07:16, 24.23s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  90%|████████▉ | 150/167 [57:43<06:43, 23.72s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  90%|█████████ | 151/167 [58:22<07:31, 28.24s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  91%|█████████ | 152/167 [58:45<06:41, 26.79s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  92%|█████████▏| 153/167 [59:07<05:54, 25.33s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  92%|█████████▏| 154/167 [59:32<05:28, 25.29s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  93%|█████████▎| 155/167 [59:49<04:31, 22.64s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  93%|█████████▎| 156/167 [1:00:04<03:43, 20.35s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  94%|█████████▍| 157/167 [1:00:29<03:37, 21.79s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  95%|█████████▍| 158/167 [1:01:04<03:51, 25.71s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  95%|█████████▌| 159/167 [1:01:21<03:04, 23.03s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  96%|█████████▌| 160/167 [1:01:36<02:24, 20.62s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  96%|█████████▋| 161/167 [1:01:50<01:51, 18.63s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  97%|█████████▋| 162/167 [1:02:15<01:43, 20.72s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  98%|█████████▊| 163/167 [1:02:36<01:22, 20.65s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  98%|█████████▊| 164/167 [1:02:50<00:55, 18.64s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  99%|█████████▉| 165/167 [1:03:22<00:45, 22.67s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning):  99%|█████████▉| 166/167 [1:03:36<00:20, 20.26s/it]The following generation flags are not valid and may be ignored: ['early_stopping']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Evaluating (with reasoning): 100%|██████████| 167/167 [1:03:59<00:00, 22.99s/it]
# 📊 FINAL RESULTS (WITH REASONING):
# Total questions: 1000
# Correct answers: 796
# Accuracy: 0.7960 (79.60%)
# Average reasoning length: 245 characters
#
# 📈 RESULTS BY CATEGORY (REASONING MODE):
# ------------------------------------------------------------
# Category                      Accuracy  Correct    Total
# ------------------------------------------------------------
# art_history                     76.19%       64       84
# civic_education                 80.95%       68       84
# current_events                  86.90%       73       84
# geography                       85.71%       72       84
# history                         90.36%       75       83
# lexicon                         89.16%       74       83
# literature                      78.31%       65       83
# morphology                      57.83%       48       83
# orthography                     74.70%       62       83
# synonyms_and_antonyms           93.98%       78       83
# syntax                          68.67%       57       83
# tourism                         72.29%       60       83
# ------------------------------------------------------------
#
# 🔍 SAMPLE PREDICTIONS (WITH REASONING):
#
# Example 1 ✅ CORRECT:
#   Category: current_events
#   Question: Chi è il regista del film "La strada"?...
#   Expected: C
#   Predicted: C
#   Reasoning length: 340 chars
#   Response excerpt: 'Il film "La strada" è un capolavoro del cinema italiano, diretto da un grande regista del neorealismo. Tra le opzioni, Vittorio De Sica è noto per fil...'
#
# Example 2 ✅ CORRECT:
#   Category: lexicon
#   Question: Uno tra i seguenti può essere un contrario di “imponenza”. Quale?...
#   Expected: B
#   Predicted: B
#   Reasoning length: 169 chars
#   Response excerpt: '"Imponenza" significa grandiosità o autorità. Tra le opzioni, "miseria" (B) è l'unica che si oppone a ricchezza o grandezza, quindi è il contrario più...'
#
# Example 3 ❌ INCORRECT:
#   Category: orthography
#   Question: Non deriva da "forca" la parola…...
#   Expected: A
#   Predicted: D
#   Reasoning length: 308 chars
#   Response excerpt: 'La parola "forca" ha radici latine ("furca"), ma non è l'origine delle altre opzioni. "Forcipe" (A) deriva dal latino "forceps", "forcola" (B) è legat...'
#
# Example 4 ❌ INCORRECT:
#   Category: synonyms_and_antonyms
#   Question: Può essere un contrario di "tetraggine"…...
#   Expected: C
#   Predicted: A
#   Reasoning length: 112 chars
#   Response excerpt: '"Tetraggine" significa rigidità o mancanza di flessibilità. Il suo contrario quindi è "flessibilità".
#
# FINALE: A...'
#
# 💾 Saving reasoning benchmark results...
# Detailed results saved to 'magistral_small_reasoning_reasoning_results.csv'
# Summary saved to 'magistral_small_reasoning_reasoning_summary.json'
#
# 🎉 REASONING EVALUATION COMPLETED!
# ============================================================
# 📊 Model: mistralai/Magistral-Small-2506
# 📊 Final accuracy: 0.7960 (79.60%)
# 📊 Total questions evaluated: 1000
# 📊 Batch size used: 6
# 🤔 Reasoning mode: ENABLED
# ⚡ Aggressive prompting: YES
# ============================================================
#
# 🧹 Final cleanup...
# Final GPU memory usage: 0.01GB
# ✅ mistralai/Magistral-Small-2506 reasoning benchmark complete! 🚀

# %%
# %%
print(f"\nReasoning benchmark completed with {accuracy:.4f} accuracy")
# Out:
# Reasoning benchmark completed with 0.7960 accuracy

# %%
# %%
# Check reasoning usage
valid_reasoning = [r for r in results if r['reasoning_length'] > 0]
avg_reasoning_length = sum(r['reasoning_length'] for r in valid_reasoning) / len(valid_reasoning) if valid_reasoning else 0
print(f"Questions with reasoning: {len(valid_reasoning)}/{len(results)} ({len(valid_reasoning)/len(results)*100:.1f}%)")
print(f"Average reasoning length: {avg_reasoning_length:.0f} characters")
# Out:
# Questions with reasoning: 1000/1000 (100.0%)
# Average reasoning length: 245 characters

# %%
# %%
print(f"Results saved with prefix: {config.output_prefix}")
# Out:
# Results saved with prefix: magistral_small_reasoning

# %%
# %%
benchmark.analyse_results_by_category(category_stats)
# Out:
# 📈 RESULTS BY CATEGORY (REASONING MODE):
# ------------------------------------------------------------
# Category                      Accuracy  Correct    Total
# ------------------------------------------------------------
# art_history                     76.19%       64       84
# civic_education                 80.95%       68       84
# current_events                  86.90%       73       84
# geography                       85.71%       72       84
# history                         90.36%       75       83
# lexicon                         89.16%       74       83
# literature                      78.31%       65       83
# morphology                      57.83%       48       83
# orthography                     74.70%       62       83
# synonyms_and_antonyms           93.98%       78       83
# syntax                          68.67%       57       83
# tourism                         72.29%       60       83
# ------------------------------------------------------------

# %%
# %%
benchmark.show_sample_predictions(results, 10)
# Out:
# 🔍 SAMPLE PREDICTIONS (WITH REASONING):
#
# Example 1 ✅ CORRECT:
#   Category: current_events
#   Question: Chi è il regista del film "La strada"?...
#   Expected: C
#   Predicted: C
#   Reasoning length: 340 chars
#   Response excerpt: 'Il film "La strada" è un capolavoro del cinema italiano, diretto da un grande regista del neorealismo. Tra le opzioni, Vittorio De Sica è noto per fil...'
#
# Example 2 ✅ CORRECT:
#   Category: lexicon
#   Question: Uno tra i seguenti può essere un contrario di “imponenza”. Quale?...
#   Expected: B
#   Predicted: B
#   Reasoning length: 169 chars
#   Response excerpt: '"Imponenza" significa grandiosità o autorità. Tra le opzioni, "miseria" (B) è l'unica che si oppone a ricchezza o grandezza, quindi è il contrario più...'
#
# Example 3 ✅ CORRECT:
#   Category: art_history
#   Question: IL PRIMO CONTATTO RADIO TRANSATLANTICO FU STABILITO DA GUGLIELMO MARCONI NEL:...
#   Expected: A
#   Predicted: A
#   Reasoning length: 218 chars
#   Response excerpt: 'Marconi è noto per i suoi esperimenti di radiotelegrafia transatlantica. La data del primo contatto transatlantico è storicamente associata all'inizio...'
#
# Example 4 ✅ CORRECT:
#   Category: synonyms_and_antonyms
#   Question: Il contrario di "eludere" è…...
#   Expected: B
#   Predicted: B
#   Reasoning length: 151 chars
#   Response excerpt: '"Eludere" significa evitare o schivare qualcosa, quindi il suo contrario è "affrontare", che implica affrontare direttamente una situazione.
#
# FINALE: ...'
#
# Example 5 ✅ CORRECT:
#   Category: syntax
#   Question: Il connettivo "comunque" nella frase "Comunque andassero le cose, io dovevo partire" ha valore:...
#   Expected: B
#   Predicted: B
#   Reasoning length: 346 chars
#   Response excerpt: 'Il connettivo "comunque" introduce una condizione che non influisce sul risultato finale, tipico del valore concessivo.
# Esempio: "Comunque vada, io sa...'
#
# Example 6 ❌ INCORRECT:
#   Category: orthography
#   Question: Non deriva da "forca" la parola…...
#   Expected: A
#   Predicted: D
#   Reasoning length: 308 chars
#   Response excerpt: 'La parola "forca" ha radici latine ("furca"), ma non è l'origine delle altre opzioni. "Forcipe" (A) deriva dal latino "forceps", "forcola" (B) è legat...'
#
# Example 7 ❌ INCORRECT:
#   Category: synonyms_and_antonyms
#   Question: Può essere un contrario di "tetraggine"…...
#   Expected: C
#   Predicted: A
#   Reasoning length: 112 chars
#   Response excerpt: '"Tetraggine" significa rigidità o mancanza di flessibilità. Il suo contrario quindi è "flessibilità".
#
# FINALE: A...'
#
# Example 8 ❌ INCORRECT:
#   Category: literature
#   Question: Chi fondò la rivista "Hermes" (1903/1906)?...
#   Expected: C
#   Predicted: D
#   Reasoning length: 135 chars
#   Response excerpt: 'La rivista "Hermes" (1903/1906) fu fondata da **Dell'Aversana**, un nome legato al mondo editoriale e letterario dell'epoca.
#
# FINALE: D...'
#
# Example 9 ❌ INCORRECT:
#   Category: lexicon
#   Question: "Mia moglie, sempre senza soldi, mi chiese il mio portfolio per andare al duty free prima che il gat...
#   Expected: B
#   Predicted: D
#   Reasoning length: 223 chars
#   Response excerpt: 'Il termine "portfolio" è corretto in italiano (portafoglio), ma "cash" e "duty free" sono anglicismi inutili in questo contesto. "Cash" può essere sos...'
#
# Example 10 ❌ INCORRECT:
#   Category: civic_education
#   Question: A norma dell'art. 86 della Costituzione, in caso di morte del Presidente della Repubblica, il Presid...
#   Expected: A
#   Predicted: B
#   Reasoning length: 281 chars
#   Response excerpt: 'L'art. 86 della Costituzione stabilisce che il Presidente della Camera dei deputati deve indire le elezioni per il nuovo Presidente della Repubblica e...'
